# %%
from pycaret.datasets import get_data 
data = get_data('diamond')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pycaret.datasets import get_data
#       2 data = get_data('diamond')
#
# ModuleNotFoundError: No module named 'pycaret'

# %%
from pycaret.utils import version
version()
# Out:
# '3.0.0'

# %%
pip install pycaret
# Out:
# ...
#   Using cached pycaret-3.0.0-py3-none-any.whl (481 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 607.3/607.3 kB 481.4 kB/s eta 0:00:0000:0100:01
# ...
#   Using cached sktime-0.17.0-py3-none-any.whl (16.1 MB)
# ...
#   Using cached kaleido-0.2.1-py2.py3-none-macosx_10_11_x86_64.whl (85.2 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.8/105.8 kB 748.1 kB/s eta 0:00:00a 0:00:01
# ...
#   Using cached plotly_resampler-0.8.3.2.tar.gz (46 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# ...
#   Using cached pyod-1.0.9.tar.gz (149 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# ...
#   Using cached tbats-1.1.2-py3-none-any.whl (43 kB)
# ...
#   Using cached importlib_metadata-6.1.0-py3-none-any.whl (21 kB)
# ...

# %%
from pycaret.datasets import get_data 
data = get_data('diamond')
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %% [markdown]
# It takes two required parameters: data and target. All the other parameters are optional.

# %%
from pycaret.datasets import get_data
data = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
pip install git+https://github.com/pycaret/pycaret.git@master --upgrade
# Out:
# ...
#   Cloning https://github.com/pycaret/pycaret.git (to revision master) to /private/var/folders/l1/lhh0nh_54_596x3k9f4slg9r0000gp/T/pip-req-build-459n29n4
#   Running command git clone --filter=blob:none --quiet https://github.com/pycaret/pycaret.git /private/var/folders/l1/lhh0nh_54_596x3k9f4slg9r0000gp/T/pip-req-build-459n29n4
#   Resolved https://github.com/pycaret/pycaret.git to commit b4cf58ab8feb982e7b2639beee5ff2b9f686d3f7
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached schemdraw-0.15-py3-none-any.whl (106 kB)
# ...
#   Attempting uninstall: schemdraw
#     Found existing installation: schemdraw 0.16
#     Uninstalling schemdraw-0.16:
#       Successfully uninstalled schemdraw-0.16
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pycaret
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pycaret.datasets import get_data
index = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
data = get_data('juice')
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0   1       CH             237        1     1.75     1.99    0.00     0.0
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 0          0          0  0.500000         1.99         1.75       0.24     No
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# ...

# %%
pip install mlflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pycaret.classification import *
clf1 = setup(data, target = 'Purchase', session_id=123, log_experiment=True, experiment_name='juice1')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 2
#       1 from pycaret.classification import *
# ----> 2 clf1 = setup(data, target = 'Purchase', session_id=123, log_experiment=True, experiment_name='juice1')
#
# ...

# %% [markdown]
# comparing models.
#
# ouput - scoring grid with avg cross validated scores.
# get_metrics: to evaluate CV/custom metrics can be added or removed using add or remove_metric.
